# %% [markdown]
# <a href="https://colab.research.google.com/github/franciscocgomes/AvaliacaoEleitoral/blob/main/Etapa_4_EDA%2C_Storytelling_e_Visualiza%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Tabela_Candidatos_Final = pd.read_csv('Tabela_Candidatos_Final.csv')

# %%
Tabela_Candidatos_Final.head()
# Out:
#                    Data_Hora              IDTweet  \
# 0  2022-07-31 12:11:15+00:00  1553714908310683648
# 1  2022-07-31 12:11:15+00:00  1553714906700062720
# 2  2022-07-31 12:11:14+00:00  1553714904426741763
# 3  2022-07-31 12:11:12+00:00  1553714897703280640
# 4  2022-07-31 12:11:12+00:00  1553714895996305408
#
#                                                Tweet Candidato  \
# 0  @RivieraNathalia Bolsonaro 22 https://t.co/sc5...      Lula
# 1  @willsilvareal @jairbolsonaro Melhor não ser c...      Lula
# 2  O bolsonaro sempre foi o que os brasileiros sa...      Lula
# 3  @guilherme_amado Dúvido que cassem o registro ...      Lula
# 4  @LulaOficial @dilmabr Sua obra estava deterior...      Lula
#
#                                          Tweet_Limpo
# 0               bolsonaro 22 https://t.co/sc5vfnnv6q
# 1    melhor não ser coveiro do que agradecer a na...
# 2  o bolsonaro sempre foi o que os brasileiros sa...
# 3   dúvido que cassem o registro da candidatura d...
# ...

# %%
pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 4.9 MB/s
# ...

# %%
import nltk
import re

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as sia

# %%
Tabela_Sentimento = Tabela_Candidatos_Final

# %%
Tabela_Candidatos_Final.head()
# Out:
#                    Data_Hora              IDTweet  \
# 0  2022-07-31 12:11:15+00:00  1553714908310683648
# 1  2022-07-31 12:11:15+00:00  1553714906700062720
# 2  2022-07-31 12:11:14+00:00  1553714904426741763
# 3  2022-07-31 12:11:12+00:00  1553714897703280640
# 4  2022-07-31 12:11:12+00:00  1553714895996305408
#
#                                                Tweet Candidato  \
# 0  @RivieraNathalia Bolsonaro 22 https://t.co/sc5...      Lula
# 1  @willsilvareal @jairbolsonaro Melhor não ser c...      Lula
# 2  O bolsonaro sempre foi o que os brasileiros sa...      Lula
# 3  @guilherme_amado Dúvido que cassem o registro ...      Lula
# 4  @LulaOficial @dilmabr Sua obra estava deterior...      Lula
#
#                                          Tweet_Limpo  \
# 0               bolsonaro 22 https://t.co/sc5vfnnv6q
# 1    melhor não ser coveiro do que agradecer a na...
# 2  o bolsonaro sempre foi o que os brasileiros sa...
# 3   dúvido que cassem o registro da candidatura d...
# ...

# %%
Tabela_Candidatos_Final.isnull()
# Out:
#     Data_Hora  IDTweet  Tweet  Candidato  Tweet_Limpo  Sentimento
# 0       False    False  False      False        False       False
# 1       False    False  False      False        False       False
# 2       False    False  False      False        False       False
# 3       False    False  False      False        False       False
# 4       False    False  False      False        False       False
# 5       False    False  False      False        False       False
# 6       False    False  False      False        False       False
# 7       False    False  False      False        False       False
# 8       False    False  False      False        False       False
# 9       False    False  False      False        False       False
# 10      False    False  False      False        False       False
# 11      False    False  False      False        False       False
# 12      False    False  False      False        False       False
# ...

# %%
Tabela_Sentimento.head()
# Out:
#                    Data_Hora              IDTweet  \
# 0  2022-07-31 12:11:15+00:00  1553714908310683648
# 1  2022-07-31 12:11:15+00:00  1553714906700062720
# 2  2022-07-31 12:11:14+00:00  1553714904426741763
# 3  2022-07-31 12:11:12+00:00  1553714897703280640
# 4  2022-07-31 12:11:12+00:00  1553714895996305408
#
#                                                Tweet Candidato  \
# 0  @RivieraNathalia Bolsonaro 22 https://t.co/sc5...      Lula
# 1  @willsilvareal @jairbolsonaro Melhor não ser c...      Lula
# 2  O bolsonaro sempre foi o que os brasileiros sa...      Lula
# 3  @guilherme_amado Dúvido que cassem o registro ...      Lula
# 4  @LulaOficial @dilmabr Sua obra estava deterior...      Lula
#
#                                          Tweet_Limpo  \
# 0               bolsonaro 22 https://t.co/sc5vfnnv6q
# 1    melhor não ser coveiro do que agradecer a na...
# 2  o bolsonaro sempre foi o que os brasileiros sa...
# 3   dúvido que cassem o registro da candidatura d...
# ...

# %%
Tabela_Sentimento.isna()
# Out:
#     Data_Hora  IDTweet  Tweet  Candidato  Tweet_Limpo  Sentimento
# 0       False    False  False      False        False       False
# 1       False    False  False      False        False       False
# 2       False    False  False      False        False       False
# 3       False    False  False      False        False       False
# 4       False    False  False      False        False       False
# 5       False    False  False      False        False       False
# 6       False    False  False      False        False       False
# 7       False    False  False      False        False       False
# 8       False    False  False      False        False       False
# 9       False    False  False      False        False       False
# 10      False    False  False      False        False       False
# 11      False    False  False      False        False       False
# 12      False    False  False      False        False       False
# ...

# %%
Tabela_Sentimento['Sentimento'] = Tabela_Sentimento['Sentimento'].apply(lambda i:sia.polarity_scores(' ',.join(re.findall(r'\w+',i.lower))))
# Out:
#   File "<ipython-input-31-210688ac6dd7>", line 1
#     Tabela_Sentimento['Sentimento'] = Tabela_Sentimento['Sentimento'].apply(lambda i:sia.polarity_scores(' ',.join(re.findall(r'\w+',i.lower))))
#                                                                                                              ^
# SyntaxError: invalid syntax
